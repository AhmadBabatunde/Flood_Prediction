# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
df.columns.values
# Out:
# array(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype=object)

# %%
df('set.rows.value')=200

# %%
df.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.117957e+06      1.117957e+06        1.117957e+06     1.117957e+06
# mean   5.589780e+05      4.921450e+00        4.926671e+00     4.955322e+00
# std    3.227265e+05      2.056387e+00        2.093879e+00     2.072186e+00
# min    0.000000e+00      0.000000e+00        0.000000e+00     0.000000e+00
# 25%    2.794890e+05      3.000000e+00        3.000000e+00     4.000000e+00
# 50%    5.589780e+05      5.000000e+00        5.000000e+00     5.000000e+00
# 75%    8.384670e+05      6.000000e+00        6.000000e+00     6.000000e+00
# max    1.117956e+06      1.600000e+01        1.800000e+01     1.600000e+01
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.117957e+06  1.117957e+06   1.117957e+06  1.117957e+06  1.117957e+06
# mean    4.942240e+00  4.942517e+00   4.934093e+00  4.955878e+00  4.927791e+00
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
df.corr()
# Out:
#                                        id  MonsoonIntensity  \
# id                               1.000000         -0.000093
# MonsoonIntensity                -0.000093          1.000000
# TopographyDrainage              -0.001518         -0.007362
# RiverManagement                 -0.000413         -0.008070
# Deforestation                   -0.000080         -0.007251
# Urbanization                     0.000580         -0.009309
# ClimateChange                   -0.000188         -0.008031
# DamsQuality                      0.000133         -0.007787
# Siltation                        0.000281         -0.007836
# AgriculturalPractices           -0.000103         -0.008232
# Encroachments                   -0.000147         -0.010309
# IneffectiveDisasterPreparedness -0.000208         -0.008032
# DrainageSystems                  0.000558         -0.009716
# CoastalVulnerability            -0.001386         -0.010659
# Landslides                       0.001078         -0.009121
# ...

# %%
X_train = df.drop(['id', 'FloodProbability'], axis =1)
X_train_2 = df.drop(['id', 'FloodProbability', 'CoastalVulnerability','Encroachments'], axis =1)

# %%
X_train.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 5                   8                5              8
# 1                 6                   7                4              4
# 2                 6                   5                6              7
# 3                 3                   4                6              5
# 4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
y_train = df.FloodProbability
y_train
# Out:
# 0          0.445
# 1          0.450
# 2          0.530
# 3          0.535
# 4          0.415
#            ...
# 1117952    0.495
# 1117953    0.480
# 1117954    0.485
# 1117955    0.495
# 1117956    0.560
# Name: FloodProbability, Length: 1117957, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
model = reg.fit(X_train_2, y_train)

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
x_test = df_test.drop(['id','CoastalVulnerability','Encroachments'], axis = 1)
pred = model.predict(x_test)

# %%
submisson = pd.read_csv('sample_submission.csv')
submisson.head()
# Out:
#         id  FloodProbability
# 0  1117957               0.5
# 1  1117958               0.5
# 2  1117959               0.5
# 3  1117960               0.5
# 4  1117961               0.5

# %%
pred
# Out:
# array([0.56549969, 0.4504782 , 0.48845227, ..., 0.6422474 , 0.52158305,
#        0.49972561])

# %%
sub_df = df_test[['id']]

# %%
sub_df['FloodProbability'] = pred

# %%
sub_df.head()
# Out:
#         id  FloodProbability
# 0  1117957          0.565500
# 1  1117958          0.450478
# 2  1117959          0.488452
# 3  1117960          0.477676
# 4  1117961          0.472268

# %%
sub_df['FloodProbability'] = sub_df['FloodProbability'].round(1)
sub_df.head()
# Out:
#         id  FloodProbability
# 0  1117957               0.6
# 1  1117958               0.5
# 2  1117959               0.5
# 3  1117960               0.5
# 4  1117961               0.5

# %%
sub_df.describe()
# Out:
#                  id  FloodProbability
# count  7.453050e+05     745305.000000
# mean   1.490609e+06          0.509196
# std    2.151512e+05          0.050380
# min    1.117957e+06          0.300000
# 25%    1.304283e+06          0.500000
# 50%    1.490609e+06          0.500000
# 75%    1.676935e+06          0.500000
# max    1.863261e+06          0.800000

# %%
sub_df.shape
# Out:
# (745305, 2)

# %%
submisson.shape
# Out:
# (745305, 2)

# %%
sub_df.to_csv('Submission.csv', index = False)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_train)

# %%
model_poly = LinearRegression()
model_poly.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
#x_poly_test = poly.fit_transform(x_test)
y_pred = model_poly.predict(x_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 2
#       1 #x_poly_test = poly.fit_transform(x_test)
# ----> 2 y_pred = model_poly.predict(x_test)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
# ...

# %%
y_pred
# Out:
# array([0.57361512, 0.45524331, 0.4547424 , ..., 0.62433022, 0.55092543,
#        0.51147209])

# %%
sub_df2 = df_test[['id']]
sub_df2['FloodProbability'] = y_pred
sub_df['FloodProbability'] = sub_df['FloodProbability'].round(1)
sub_df.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12112\1160864918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df2['FloodProbability'] = y_pred
#         id  FloodProbability
# 0  1117957               0.6
# 1  1117958               0.5
# 2  1117959               0.5
# 3  1117960               0.5
# 4  1117961               0.5

# %%
from sklearn.ensemble import RandomForestClassifier
model_forest = RandomForestClassifier(n_estimators=100, random_state=42)
# Perform equal-width binning on the target variable
bins = pd.cut(y_train, bins=5, labels=False)

# Convert binned target variable to categorical
y_train_categorical = pd.cut(y_train, bins=5, labels=['Low', 'Medium-Low', 'Medium', 'Medium-High', 'High'])

# Train RandomForestClassifier
model_forest.fit(X_train, y_train_categorical)
# Out:
# RandomForestClassifier(random_state=42)

# %%
predicted_probabilities = model_forest.predict_proba(x_test)
max_probabilities = np.max(predicted_probabilities, axis=1)

# %%
predicted_probabilities.shape
# Out:
# (745305, 5)

# %%
max_probabilities.shape
# Out:
# (745305,)

# %%
sub_df3 = df_test[['id']]
sub_df3['FloodProbability'] = max_probabilities
sub_df3['FloodProbability'] = sub_df3['FloodProbability'].round(1)
sub_df3.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12112\1337548198.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df3['FloodProbability'] = max_probabilities
# C:\Users\pc\AppData\Local\Temp\ipykernel_12112\1337548198.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df3['FloodProbability'] = sub_df3['FloodProbability'].round(1)
#         id  FloodProbability
# 0  1117957               0.5
# 1  1117958               0.5
# 2  1117959               0.6
# 3  1117960               0.7
# ...

# %%
sub_df3.to_csv('Submission_3.csv', index = False)
